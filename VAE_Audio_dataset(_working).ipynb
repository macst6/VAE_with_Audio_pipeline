# %%
#Preprocessing Pipeline
#Load the file
#pad the signal if necessay
#Extracting log spectogram using Librosa
#Normalize Spectogram
#Save the Normalized Spectogram

# %%
# !pip install librosa
import librosa
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.56.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.7.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.6)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (67.7.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (3.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (23.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)

# %%
import numpy as np
import os
import pickle

# %%
"""
1- load a file
2- pad the signal (if necessary)
3- extracting log spectrogram from signal
4- normalise spectrogram
5- save the normalised spectrogram

PreprocessingPipeline
"""
import os
import pickle

import librosa
import numpy as np


class Loader:
    """Loader is responsible for loading an audio file."""

    #We are passing a constructor in the loader Class that will construct the class
    #It has following arguments
    # Sample rate -> we load audio file with this
    # Duration -> How long audio will play (sec)
    # Mono -> it is boolean and tells us if audio is mono or stereo
    def __init__(self, sample_rate, duration, mono):
        self.sample_rate = sample_rate
        self.duration = duration
        self.mono = mono

    def load(self, file_path):
        #This is like a thin wrapper around librosa
        #Now loading the files

        signal = librosa.load(file_path,
                              sr=self.sample_rate,
                              duration=self.duration,
                              mono=self.mono)[0]
        return signal

#Pad the signal if necessay
class Padder:
    """Padder is responsible to apply padding to an array."""

    #Padder is the Function to padding the data in array
    #We will make a constructor

    def __init__(self, mode="constant"):
        self.mode = mode

    #This function is for left Padding
    def left_pad(self, array, num_missing_items):
        #[1,2,3] -> 2 -> [0,0,1,2,3]
        padded_array = np.pad(array,
                              (num_missing_items, 0),
                              mode=self.mode)
        return padded_array


    #This function is for right Padding
    def right_pad(self, array, num_missing_items):
        #[1,2,3] -> 2 -> [1,2,3,0,0]
        padded_array = np.pad(array,
                              (0, num_missing_items),
                              mode=self.mode)
        return padded_array

#Extracting log spectogram using Librosa
class LogSpectrogramExtractor:
    """LogSpectrogramExtractor extracts log spectrograms (in dB) from a
    time-series signal.
    """

    #LogSpectogramExtractor creates a log spectogram in dB from a time series Signal
    def __init__(self, frame_size, hop_length):
        self.frame_size = frame_size
        self.hop_length = hop_length


    def extract(self, signal):
        stft = librosa.stft(signal,
                            n_fft=self.frame_size,
                            hop_length=self.hop_length)[:-1]
        spectrogram = librosa.amplitude_to_db(stft)
        #(1+frame_size/2,num_frame)  1024 -> 513 -> 512

        spectrogram = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(spectrogram)
        return log_spectrogram


class MinMaxNormaliser:
    """MinMaxNormaliser applies min max normalisation to an array."""

    #MinMax Normalization applies min max normalization to array
    #We take a minimum value that is mapped close to zero
    #We take a maximum value that is mapped close to one

    def __init__(self, min_val, max_val):
        self.min = min_val
        self.max = max_val

    def normalise(self, array):
        #array will be squished between 0 and 1
        #1st step to Normalize array -> (array-array.min())/(array.max()-array.min())
        norm_array = (array - array.min()) / (array.max() - array.min())
        #2nd step to Normalize array -> Normalize array + (self.max - self.min)
        norm_array = norm_array * (self.max - self.min) + self.min
        return norm_array

    def denormalise(self, norm_array, original_min, original_max):
        #array will be squished between 0 and 1
        #1st step to Normalize array -> (norm_array-self.min)/(self.max()-self.min())
        array = (norm_array - self.min) / (self.max - self.min)
        #2nd step to Normalize array -> array * (original_max - original_min) + original_min
        array = array * (original_max - original_min) + original_min
        return array

#Save the Normalized Spectogram
class Saver:
    """saver is responsible to save features, and the min max values."""

    #We need feature save directory and min max value directory as the constructors that make the saver
    def __init__(self, feature_save_dir, min_max_values_save_dir):
        self.feature_save_dir = feature_save_dir
        self.min_max_values_save_dir = min_max_values_save_dir

    def save_feature(self, feature, file_path):
        #We generated save path and generated the path
        save_path = self._generate_save_path(file_path)
        #save the path of the feature
        np.save(save_path, feature)
        return save_path

    def save_min_max_values(self, min_max_values):
        #save the min max directory to a file named min max pkl
        save_path = os.path.join(self.min_max_values_save_dir,
                                 "min_max_values.pkl")
        self._save(min_max_values, save_path)

    @staticmethod
    def _save(data, save_path):
        with open(save_path, "wb") as f:
            pickle.dump(data, f)

    def _generate_save_path(self, file_path):
        file_name = os.path.split(file_path)[1]
        save_path = os.path.join(self.feature_save_dir, file_name + ".npy")
        return save_path


class PreprocessingPipeline:
    """PreprocessingPipeline processes audio files in a directory, applying
    the following steps to each file:
        1- load a file
        2- pad the signal (if necessary)
        3- extracting log spectrogram from signal
        4- normalise spectrogram
        5- save the normalised spectrogram

    Storing the min max values for all the log spectrograms.
    """

    def __init__(self):
        self.padder = None
        self.extractor = None
        self.normaliser = None
        self.saver = None
        self.min_max_values = {}
        self._loader = None
        self._num_expected_samples = None

    @property
    def loader(self):
        return self._loader

    @loader.setter
    def loader(self, loader):
        self._loader = loader
        self._num_expected_samples = int(loader.sample_rate * loader.duration)

    def process(self, audio_files_dir):


        for root, _, files in os.walk(audio_files_dir):
            for file in files:
                file_path = os.path.join(root, file)
                self._process_file(file_path)
                print(f"Processed file {file_path}")
        self.saver.save_min_max_values(self.min_max_values)

    def _process_file(self, file_path):

        #it is the bulk of the class
        #We will load the signal
        signal = self.loader.load(file_path)
        #Now we are deciding wether we want to apply padding or not
        #Then we are moving to is padding necessary function
        if self._is_padding_necessary(signal):
            #if the signal need padding then we will apply that to the signal
            signal = self._apply_padding(signal)
        #Now we are extracting the feature
        feature = self.extractor.extract(signal)
        #Then we will save the normalized feature
        norm_feature = self.normaliser.normalise(feature)
        #Then we will save the path
        save_path = self.saver.save_feature(norm_feature, file_path)
        #We also want
        self._store_min_max_value(save_path, feature.min(), feature.max())

    def _is_padding_necessary(self, signal):
        #How are we gonna check if the signal needs padding or not
        #Duration is fixed and we know number of expected samples
        #So if the length of the signal is less than expected samples then we provide results as boolean value
        if len(signal) < self._num_expected_samples:
            return True
        return False

    def _apply_padding(self, signal):
        #Here we will give the signal
        #Number of missing samples = Number of expected samples - length of signal
        num_missing_samples = self._num_expected_samples - len(signal)
        padded_signal = self.padder.right_pad(signal, num_missing_samples)
        return padded_signal

    def _store_min_max_value(self, save_path, min_val, max_val):
        #This will store the dictionary of minimum and maximum value
        self.min_max_values[save_path] = {
            "min": min_val,
            "max": max_val
        }

# %%
if __name__ == "__main__":
    FRAME_SIZE = 512
    HOP_LENGTH = 256
    DURATION = 0.74  # in seconds
    SAMPLE_RATE = 22050
    MONO = True

    SPECTROGRAMS_SAVE_DIR = "/content/drive/MyDrive/Spectogram/"
    MIN_MAX_VALUES_SAVE_DIR = "/content/drive/MyDrive/Min_max_value/"
    FILES_DIR = "/content/drive/MyDrive/recordings/"

    # instantiate all objects
    loader = Loader(SAMPLE_RATE, DURATION, MONO)
    padder = Padder()
    log_spectrogram_extractor = LogSpectrogramExtractor(FRAME_SIZE, HOP_LENGTH)
    min_max_normaliser = MinMaxNormaliser(0, 1)
    saver = Saver(SPECTROGRAMS_SAVE_DIR, MIN_MAX_VALUES_SAVE_DIR)

    preprocessing_pipeline = PreprocessingPipeline()
    preprocessing_pipeline.loader = loader
    preprocessing_pipeline.padder = padder
    preprocessing_pipeline.extractor = log_spectrogram_extractor
    preprocessing_pipeline.normaliser = min_max_normaliser
    preprocessing_pipeline.saver = saver

    preprocessing_pipeline.process(FILES_DIR)
# Out:
# <ipython-input-26-39b3601fc5ee>:65: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   spectrogram = librosa.amplitude_to_db(stft)
# Processed file /content/drive/MyDrive/recordings/5_george_24.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_5.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_17.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_39.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_44.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_41.wav
# Processed file /content/drive/MyDrive/recordings/6_george_46.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_39.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_37.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_24.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_49.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_38.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_1.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_38.wav
# Processed file /content/drive/MyDrive/recordings/5_george_26.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_47.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_10.wav
# Processed file /content/drive/MyDrive/recordings/5_george_22.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_49.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_15.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_8.wav
# Processed file /content/drive/MyDrive/recordings/4_george_7.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_13.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_3.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_49.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_8.wav
# Processed file /content/drive/MyDrive/recordings/5_george_12.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_2.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_24.wav
# Processed file /content/drive/MyDrive/recordings/4_george_44.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_37.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_49.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_41.wav
# Processed file /content/drive/MyDrive/recordings/3_george_4.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_26.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_35.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_8.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_25.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_6.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_29.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_29.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_11.wav
# Processed file /content/drive/MyDrive/recordings/5_george_46.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_16.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_0.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_16.wav
# Processed file /content/drive/MyDrive/recordings/2_lucas_9.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_34.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_37.wav
# Processed file /content/drive/MyDrive/recordings/6_george_29.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_28.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_9.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_24.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_40.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_36.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_4.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_24.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_37.wav
# Processed file /content/drive/MyDrive/recordings/3_george_36.wav
# Processed file /content/drive/MyDrive/recordings/6_george_1.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_1.wav
# Processed file /content/drive/MyDrive/recordings/5_george_27.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_16.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_2.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_45.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_20.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_46.wav
# Processed file /content/drive/MyDrive/recordings/3_george_27.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_12.wav
# Processed file /content/drive/MyDrive/recordings/8_george_5.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_39.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_36.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_2.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_1.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_42.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_16.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_34.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_33.wav
# Processed file /content/drive/MyDrive/recordings/5_george_6.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_45.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_15.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_47.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_30.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_35.wav
# Processed file /content/drive/MyDrive/recordings/8_george_44.wav
# Processed file /content/drive/MyDrive/recordings/8_george_0.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_42.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_11.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_31.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_19.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_17.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_9.wav
# Processed file /content/drive/MyDrive/recordings/3_george_42.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_46.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_9.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_11.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_18.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_49.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_49.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_8.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_43.wav
# Processed file /content/drive/MyDrive/recordings/3_george_12.wav
# Processed file /content/drive/MyDrive/recordings/5_george_25.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_38.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_48.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_45.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_40.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_21.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_7.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_16.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_18.wav
# Processed file /content/drive/MyDrive/recordings/5_george_16.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_37.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_27.wav
# Processed file /content/drive/MyDrive/recordings/6_george_44.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_49.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_38.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_11.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_27.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_0.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_6.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_7.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_33.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_10.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_28.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_2.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_40.wav
# Processed file /content/drive/MyDrive/recordings/5_george_35.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_48.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_48.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_4.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_9.wav
# Processed file /content/drive/MyDrive/recordings/6_george_3.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_7.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_5.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_27.wav
# Processed file /content/drive/MyDrive/recordings/3_george_49.wav
# Processed file /content/drive/MyDrive/recordings/6_george_24.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_40.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_9.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_6.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_45.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_0.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_33.wav
# Processed file /content/drive/MyDrive/recordings/3_george_22.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_11.wav
# Processed file /content/drive/MyDrive/recordings/8_george_11.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_30.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_22.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_6.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_35.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_23.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_25.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_36.wav
# Processed file /content/drive/MyDrive/recordings/8_george_14.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_3.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_15.wav
# Processed file /content/drive/MyDrive/recordings/8_george_27.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_3.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_24.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_16.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_27.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_7.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_34.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_42.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_30.wav
# Processed file /content/drive/MyDrive/recordings/4_george_12.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_38.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_14.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_4.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_43.wav
# Processed file /content/drive/MyDrive/recordings/8_george_6.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_46.wav
# Processed file /content/drive/MyDrive/recordings/3_george_2.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_31.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_32.wav
# Processed file /content/drive/MyDrive/recordings/3_george_6.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_6.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_14.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_39.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_9.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_13.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_24.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_47.wav
# Processed file /content/drive/MyDrive/recordings/8_george_9.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_24.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_46.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_41.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_13.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_49.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_41.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_1.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_31.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_37.wav
# Processed file /content/drive/MyDrive/recordings/5_george_15.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_14.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_47.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_3.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_18.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_21.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_44.wav
# Processed file /content/drive/MyDrive/recordings/7_george_37.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_49.wav
# Processed file /content/drive/MyDrive/recordings/4_george_4.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_17.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_4.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_48.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_40.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_31.wav
# Processed file /content/drive/MyDrive/recordings/4_george_29.wav
# Processed file /content/drive/MyDrive/recordings/5_george_10.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_34.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_16.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_44.wav
# Processed file /content/drive/MyDrive/recordings/8_george_49.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_26.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_9.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_41.wav
# Processed file /content/drive/MyDrive/recordings/4_george_21.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_20.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_9.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_45.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_7.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_42.wav
# Processed file /content/drive/MyDrive/recordings/6_george_9.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_10.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_43.wav
# Processed file /content/drive/MyDrive/recordings/4_george_38.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_29.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_10.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_0.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_30.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_26.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_9.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_34.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_35.wav
# Processed file /content/drive/MyDrive/recordings/6_george_17.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_33.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_22.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_16.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_19.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_29.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_40.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_20.wav
# Processed file /content/drive/MyDrive/recordings/4_george_22.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_4.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_33.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_6.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_1.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_2.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_23.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_47.wav
# Processed file /content/drive/MyDrive/recordings/5_george_44.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_14.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_16.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_46.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_12.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_2.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_45.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_16.wav
# Processed file /content/drive/MyDrive/recordings/6_george_39.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_3.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_5.wav
# Processed file /content/drive/MyDrive/recordings/8_george_28.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_29.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_5.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_3.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_38.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_24.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_29.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_15.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_10.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_47.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_7.wav
# Processed file /content/drive/MyDrive/recordings/5_george_47.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_14.wav
# Processed file /content/drive/MyDrive/recordings/4_george_34.wav
# Processed file /content/drive/MyDrive/recordings/8_george_23.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_12.wav
# Processed file /content/drive/MyDrive/recordings/4_george_39.wav
# Processed file /content/drive/MyDrive/recordings/7_george_41.wav
# Processed file /content/drive/MyDrive/recordings/3_george_9.wav
# Processed file /content/drive/MyDrive/recordings/6_george_38.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_23.wav
# Processed file /content/drive/MyDrive/recordings/3_george_34.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_4.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_9.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_7.wav
# Processed file /content/drive/MyDrive/recordings/6_george_49.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_5.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_5.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_42.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_9.wav
# Processed file /content/drive/MyDrive/recordings/6_george_35.wav
# Processed file /content/drive/MyDrive/recordings/3_george_20.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_30.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_32.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_31.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_9.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_41.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_31.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_2.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_25.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_16.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_40.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_25.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_2.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_6.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_15.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_6.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_22.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_22.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_25.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_35.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_17.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_35.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_36.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_39.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_39.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_47.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_17.wav
# Processed file /content/drive/MyDrive/recordings/4_george_15.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_1.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_15.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_30.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_27.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_3.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_13.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_21.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_18.wav
# Processed file /content/drive/MyDrive/recordings/7_george_36.wav
# Processed file /content/drive/MyDrive/recordings/3_george_25.wav
# Processed file /content/drive/MyDrive/recordings/8_george_21.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_42.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_46.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_34.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_5.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_45.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_49.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_13.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_6.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_28.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_10.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_2.wav
# Processed file /content/drive/MyDrive/recordings/4_george_37.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_4.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_37.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_19.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_28.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_0.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_20.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_6.wav
# Processed file /content/drive/MyDrive/recordings/7_george_27.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_26.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_4.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_9.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_3.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_12.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_7.wav
# Processed file /content/drive/MyDrive/recordings/4_george_23.wav
# Processed file /content/drive/MyDrive/recordings/4_george_31.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_41.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_40.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_30.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_30.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_3.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_31.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_3.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_31.wav
# Processed file /content/drive/MyDrive/recordings/8_george_42.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_48.wav
# Processed file /content/drive/MyDrive/recordings/3_george_24.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_14.wav
# Processed file /content/drive/MyDrive/recordings/7_george_4.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_47.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_39.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_0.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_24.wav
# Processed file /content/drive/MyDrive/recordings/4_george_13.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_9.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_29.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_5.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_43.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_40.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_23.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_44.wav
# Processed file /content/drive/MyDrive/recordings/6_george_11.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_36.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_6.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_32.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_21.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_3.wav
# Processed file /content/drive/MyDrive/recordings/6_george_8.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_29.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_23.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_30.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_27.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_8.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_15.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_29.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_31.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_32.wav
# Processed file /content/drive/MyDrive/recordings/4_george_30.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_47.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_4.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_26.wav
# Processed file /content/drive/MyDrive/recordings/5_george_39.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_18.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_17.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_6.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_28.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_0.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_35.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_25.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_45.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_34.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_32.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_47.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_0.wav
# Processed file /content/drive/MyDrive/recordings/4_george_24.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_2.wav
# Processed file /content/drive/MyDrive/recordings/8_george_43.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_30.wav
# Processed file /content/drive/MyDrive/recordings/5_george_0.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_34.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_42.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_21.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_38.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_25.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_48.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_16.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_9.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_26.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_47.wav
# Processed file /content/drive/MyDrive/recordings/4_george_6.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_21.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_8.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_46.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_44.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_14.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_38.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_6.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_41.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_13.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_12.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_10.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_46.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_32.wav
# Processed file /content/drive/MyDrive/recordings/7_george_29.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_23.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_20.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_29.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_36.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_19.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_47.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_23.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_40.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_21.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_32.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_34.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_5.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_29.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_43.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_27.wav
# Processed file /content/drive/MyDrive/recordings/7_george_46.wav
# Processed file /content/drive/MyDrive/recordings/8_george_34.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_26.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_28.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_48.wav
# Processed file /content/drive/MyDrive/recordings/5_george_20.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_43.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_28.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_23.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_12.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_27.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_43.wav
# Processed file /content/drive/MyDrive/recordings/6_george_20.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_1.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_1.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_30.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_19.wav
# Processed file /content/drive/MyDrive/recordings/3_george_46.wav
# Processed file /content/drive/MyDrive/recordings/6_george_15.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_31.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_13.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_11.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_24.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_39.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_49.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_33.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_8.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_32.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_43.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_36.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_11.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_45.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_43.wav
# Processed file /content/drive/MyDrive/recordings/7_george_39.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_8.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_38.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_26.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_5.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_13.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_0.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_40.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_3.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_45.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_44.wav
# Processed file /content/drive/MyDrive/recordings/7_george_8.wav
# Processed file /content/drive/MyDrive/recordings/2_lucas_6.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_14.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_33.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_30.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_48.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_45.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_42.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_42.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_10.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_34.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_19.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_21.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_0.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_48.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_34.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_8.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_18.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_13.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_33.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_3.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_42.wav
# Processed file /content/drive/MyDrive/recordings/7_george_28.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_20.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_25.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_12.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_12.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_41.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_29.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_32.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_7.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_17.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_34.wav
# Processed file /content/drive/MyDrive/recordings/5_george_7.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_40.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_45.wav
# Processed file /content/drive/MyDrive/recordings/8_george_20.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_6.wav
# Processed file /content/drive/MyDrive/recordings/5_george_33.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_8.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_19.wav
# Processed file /content/drive/MyDrive/recordings/3_george_29.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_4.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_32.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_46.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_46.wav
# Processed file /content/drive/MyDrive/recordings/4_george_18.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_40.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_45.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_49.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_19.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_14.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_41.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_48.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_13.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_20.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_23.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_12.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_12.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_3.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_1.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_13.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_49.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_0.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_2.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_39.wav
# Processed file /content/drive/MyDrive/recordings/4_george_0.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_1.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_13.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_39.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_34.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_42.wav
# Processed file /content/drive/MyDrive/recordings/7_george_17.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_18.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_41.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_35.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_40.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_11.wav
# Processed file /content/drive/MyDrive/recordings/8_george_38.wav
# Processed file /content/drive/MyDrive/recordings/6_george_36.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_20.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_33.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_31.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_44.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_23.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_1.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_0.wav
# Processed file /content/drive/MyDrive/recordings/5_george_8.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_47.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_8.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_10.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_32.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_25.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_21.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_45.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_23.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_31.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_22.wav
# Processed file /content/drive/MyDrive/recordings/3_george_48.wav
# Processed file /content/drive/MyDrive/recordings/6_george_30.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_44.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_26.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_20.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_35.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_45.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_38.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_15.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_19.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_21.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_36.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_43.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_29.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_44.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_24.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_32.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_33.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_28.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_43.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_2.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_47.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_9.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_33.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_11.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_20.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_48.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_46.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_14.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_32.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_43.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_11.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_12.wav
# Processed file /content/drive/MyDrive/recordings/9_george_6.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_42.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_27.wav
# Processed file /content/drive/MyDrive/recordings/9_george_31.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_34.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_4.wav
# Processed file /content/drive/MyDrive/recordings/9_george_22.wav
# Processed file /content/drive/MyDrive/recordings/9_george_37.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_16.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_14.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_46.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_6.wav
# Processed file /content/drive/MyDrive/recordings/9_george_44.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_45.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_48.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_24.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_42.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_1.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_3.wav
# Processed file /content/drive/MyDrive/recordings/9_george_15.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_19.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_4.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_18.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_22.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_16.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_13.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_27.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_21.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_28.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_18.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_27.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_38.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_1.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_41.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_40.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_30.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_39.wav
# Processed file /content/drive/MyDrive/recordings/9_george_8.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_44.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_23.wav
# Processed file /content/drive/MyDrive/recordings/9_george_48.wav
# Processed file /content/drive/MyDrive/recordings/9_george_9.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_49.wav
# Processed file /content/drive/MyDrive/recordings/9_george_42.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_40.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_10.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_47.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_22.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_33.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_2.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_21.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_19.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_7.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_23.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_34.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_4.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_21.wav
# Processed file /content/drive/MyDrive/recordings/9_george_34.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_29.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_27.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_46.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_6.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_0.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_45.wav
# Processed file /content/drive/MyDrive/recordings/9_george_23.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_3.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_22.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_8.wav
# Processed file /content/drive/MyDrive/recordings/9_george_2.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_27.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_40.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_10.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_19.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_2.wav
# Processed file /content/drive/MyDrive/recordings/9_george_5.wav
# Processed file /content/drive/MyDrive/recordings/9_theo_22.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_1.wav
# Processed file /content/drive/MyDrive/recordings/9_george_40.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_22.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_14.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_37.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_1.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_4.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_33.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_32.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_16.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_36.wav
# Processed file /content/drive/MyDrive/recordings/8_yweweler_31.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_31.wav
# Processed file /content/drive/MyDrive/recordings/9_lucas_7.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_31.wav
# Processed file /content/drive/MyDrive/recordings/9_nicolas_29.wav
# Processed file /content/drive/MyDrive/recordings/9_yweweler_24.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_48.wav
# Processed file /content/drive/MyDrive/recordings/9_george_4.wav
# Processed file /content/drive/MyDrive/recordings/9_jackson_8.wav
# ...
# Processed file /content/drive/MyDrive/recordings/6_lucas_33.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_39.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_24.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_41.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_17.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_9.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_4.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_10.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_27.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_24.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_0.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_49.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_14.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_24.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_36.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_2.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_19.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_11.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_21.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_16.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_4.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_28.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_22.wav
# Processed file /content/drive/MyDrive/recordings/7_george_48.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_11.wav
# Processed file /content/drive/MyDrive/recordings/7_george_31.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_22.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_8.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_36.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_8.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_34.wav
# Processed file /content/drive/MyDrive/recordings/6_george_22.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_18.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_15.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_32.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_44.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_48.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_12.wav
# Processed file /content/drive/MyDrive/recordings/7_george_3.wav
# Processed file /content/drive/MyDrive/recordings/6_george_16.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_11.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_32.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_5.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_38.wav
# Processed file /content/drive/MyDrive/recordings/8_george_19.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_19.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_48.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_4.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_33.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_17.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_45.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_24.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_22.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_40.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_12.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_44.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_17.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_19.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_26.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_44.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_31.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_43.wav
# Processed file /content/drive/MyDrive/recordings/4_george_26.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_35.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_34.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_40.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_13.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_44.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_43.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_46.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_36.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_35.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_42.wav
# Processed file /content/drive/MyDrive/recordings/7_george_15.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_41.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_15.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_11.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_44.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_21.wav
# Processed file /content/drive/MyDrive/recordings/8_george_18.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_16.wav
# Processed file /content/drive/MyDrive/recordings/4_george_33.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_18.wav
# Processed file /content/drive/MyDrive/recordings/7_george_2.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_15.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_5.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_0.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_37.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_14.wav
# Processed file /content/drive/MyDrive/recordings/5_george_40.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_26.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_40.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_13.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_28.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_28.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_10.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_47.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_28.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_5.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_39.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_36.wav
# Processed file /content/drive/MyDrive/recordings/3_george_15.wav
# Processed file /content/drive/MyDrive/recordings/5_george_23.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_25.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_7.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_7.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_27.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_34.wav
# Processed file /content/drive/MyDrive/recordings/7_george_44.wav
# Processed file /content/drive/MyDrive/recordings/8_george_24.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_49.wav
# Processed file /content/drive/MyDrive/recordings/3_george_35.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_49.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_24.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_40.wav
# Processed file /content/drive/MyDrive/recordings/7_george_40.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_43.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_37.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_49.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_25.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_41.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_4.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_25.wav
# Processed file /content/drive/MyDrive/recordings/4_george_19.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_46.wav
# Processed file /content/drive/MyDrive/recordings/7_george_24.wav
# Processed file /content/drive/MyDrive/recordings/7_george_5.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_31.wav
# Processed file /content/drive/MyDrive/recordings/7_george_49.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_35.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_0.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_40.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_23.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_28.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_38.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_27.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_38.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_28.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_30.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_35.wav
# Processed file /content/drive/MyDrive/recordings/6_george_5.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_3.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_22.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_35.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_46.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_26.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_33.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_20.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_16.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_47.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_49.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_34.wav
# Processed file /content/drive/MyDrive/recordings/5_george_4.wav
# Processed file /content/drive/MyDrive/recordings/8_george_32.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_15.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_23.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_42.wav
# Processed file /content/drive/MyDrive/recordings/8_theo_0.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_42.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_1.wav
# Processed file /content/drive/MyDrive/recordings/7_george_25.wav
# Processed file /content/drive/MyDrive/recordings/7_george_23.wav
# Processed file /content/drive/MyDrive/recordings/7_jackson_46.wav
# Processed file /content/drive/MyDrive/recordings/6_lucas_20.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_34.wav
# Processed file /content/drive/MyDrive/recordings/6_george_4.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_39.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_31.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_27.wav
# Processed file /content/drive/MyDrive/recordings/3_george_23.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_19.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_23.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_2.wav
# Processed file /content/drive/MyDrive/recordings/3_jackson_7.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_17.wav
# Processed file /content/drive/MyDrive/recordings/8_lucas_30.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_19.wav
# Processed file /content/drive/MyDrive/recordings/5_george_32.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_43.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_47.wav
# Processed file /content/drive/MyDrive/recordings/7_george_35.wav
# Processed file /content/drive/MyDrive/recordings/7_theo_47.wav
# Processed file /content/drive/MyDrive/recordings/4_nicolas_38.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_1.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_38.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_34.wav
# Processed file /content/drive/MyDrive/recordings/4_george_25.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_37.wav
# Processed file /content/drive/MyDrive/recordings/7_george_14.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_23.wav
# Processed file /content/drive/MyDrive/recordings/6_theo_39.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_10.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_22.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_23.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_21.wav
# Processed file /content/drive/MyDrive/recordings/6_george_26.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_31.wav
# Processed file /content/drive/MyDrive/recordings/5_yweweler_10.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_24.wav
# Processed file /content/drive/MyDrive/recordings/3_theo_21.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_23.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_4.wav
# Processed file /content/drive/MyDrive/recordings/5_george_36.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_10.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_47.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_3.wav
# Processed file /content/drive/MyDrive/recordings/4_george_43.wav
# Processed file /content/drive/MyDrive/recordings/4_jackson_17.wav
# Processed file /content/drive/MyDrive/recordings/2_nicolas_37.wav
# Processed file /content/drive/MyDrive/recordings/4_yweweler_36.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_24.wav
# Processed file /content/drive/MyDrive/recordings/6_george_13.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_48.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_3.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_26.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_5.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_14.wav
# Processed file /content/drive/MyDrive/recordings/7_nicolas_37.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_46.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_41.wav
# Processed file /content/drive/MyDrive/recordings/6_george_12.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_44.wav
# Processed file /content/drive/MyDrive/recordings/6_yweweler_44.wav
# Processed file /content/drive/MyDrive/recordings/8_nicolas_14.wav
# Processed file /content/drive/MyDrive/recordings/3_yweweler_48.wav
# Processed file /content/drive/MyDrive/recordings/3_george_33.wav
# Processed file /content/drive/MyDrive/recordings/7_yweweler_37.wav
# Processed file /content/drive/MyDrive/recordings/8_jackson_11.wav
# Processed file /content/drive/MyDrive/recordings/5_theo_3.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_48.wav
# Processed file /content/drive/MyDrive/recordings/6_jackson_19.wav
# Processed file /content/drive/MyDrive/recordings/3_lucas_33.wav
# Processed file /content/drive/MyDrive/recordings/6_nicolas_35.wav
# Processed file /content/drive/MyDrive/recordings/5_jackson_33.wav
# Processed file /content/drive/MyDrive/recordings/7_lucas_31.wav
# Processed file /content/drive/MyDrive/recordings/2_theo_4.wav
# Processed file /content/drive/MyDrive/recordings/3_nicolas_26.wav
# Processed file /content/drive/MyDrive/recordings/5_nicolas_0.wav
# Processed file /content/drive/MyDrive/recordings/5_lucas_45.wav
# Processed file /content/drive/MyDrive/recordings/4_lucas_32.wav
# Processed file /content/drive/MyDrive/recordings/4_george_27.wav
# Processed file /content/drive/MyDrive/recordings/3_george_7.wav
# Processed file /content/drive/MyDrive/recordings/2_yweweler_25.wav
# Processed file /content/drive/MyDrive/recordings/8_george_16.wav
# Processed file /content/drive/MyDrive/recordings/4_theo_44.wav

# %%
import pickle
import os
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization, \
    Flatten, Dense, Reshape, Conv2DTranspose, Activation, Lambda
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
import numpy as np
import tensorflow as tf
from tensorflow.python.framework.ops import disable_eager_execution
from tensorflow.keras.datasets import mnist

disable_eager_execution()


def _calculate_reconstruction_loss(y_target, y_predicted):
    error = y_target - y_predicted
    reconstruction_loss = K.mean(K.square(error), axis=[1, 2, 3])
    return reconstruction_loss


def calculate_kl_loss(model):
    # wrap `_calculate_kl_loss` such that it takes the model as an argument,
    # returns a function which can take arbitrary number of arguments
    # (for compatibility with `metrics` and utility in the loss function)
    # and returns the kl loss
    def _calculate_kl_loss(*args):
        kl_loss = -0.5 * K.sum(1 + model.log_variance - K.square(model.mu) -
                               K.exp(model.log_variance), axis=1)
        return kl_loss
    return _calculate_kl_loss


class VAE:
    """
    VAE represents a Deep Convolutional variational autoencoder architecture
    with mirrored encoder and decoder components.
    """

    def __init__(self,
                 input_shape,
                 conv_filters,
                 conv_kernels,
                 conv_strides,
                 latent_space_dim):
        self.input_shape = input_shape # [28, 28, 1]
        self.conv_filters = conv_filters # [2, 4, 8]
        self.conv_kernels = conv_kernels # [3, 5, 3]
        self.conv_strides = conv_strides # [1, 2, 2]
        self.latent_space_dim = latent_space_dim # 2
        self.reconstruction_loss_weight = 1000

        self.encoder = None
        self.decoder = None
        self.model = None

        self._num_conv_layers = len(conv_filters)
        self._shape_before_bottleneck = None
        self._model_input = None

        self._build()

    def summary(self):
        self.encoder.summary()
        self.decoder.summary()
        self.model.summary()

    def compile(self, learning_rate=0.001):
        optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate)
        self.model.compile(optimizer=optimizer,
                           loss=self._calculate_combined_loss,
                           metrics=[_calculate_reconstruction_loss,
                                    calculate_kl_loss(self)])

    def train(self, x_train, batch_size, num_epochs):
        self.model.fit(x_train,
                       x_train,
                       batch_size=batch_size,
                       epochs=num_epochs,
                       shuffle=True)

    def save(self, save_folder="."):
        self._create_folder_if_it_doesnt_exist(save_folder)
        self._save_parameters(save_folder)
        self._save_weights(save_folder)

    def load_weights(self, weights_path):
        self.model.load_weights(weights_path)

    def reconstruct(self, images):
        latent_representations = self.encoder.predict(images)
        reconstructed_images = self.decoder.predict(latent_representations)
        return reconstructed_images, latent_representations

    @classmethod
    def load(cls, save_folder="."):
        parameters_path = os.path.join(save_folder, "parameters.pkl")
        with open(parameters_path, "rb") as f:
            parameters = pickle.load(f)
        autoencoder = VAE(*parameters)
        weights_path = os.path.join(save_folder, "weights.h5")
        autoencoder.load_weights(weights_path)
        return autoencoder

    def _calculate_combined_loss(self, y_target, y_predicted):
        reconstruction_loss = _calculate_reconstruction_loss(y_target, y_predicted)
        kl_loss = calculate_kl_loss(self)()
        combined_loss = self.reconstruction_loss_weight * reconstruction_loss\
                                                         + kl_loss
        return combined_loss

    def _create_folder_if_it_doesnt_exist(self, folder):
        if not os.path.exists(folder):
            os.makedirs(folder)

    def _save_parameters(self, save_folder):
        parameters = [
            self.input_shape,
            self.conv_filters,
            self.conv_kernels,
            self.conv_strides,
            self.latent_space_dim
        ]
        save_path = os.path.join(save_folder, "parameters.pkl")
        with open(save_path, "wb") as f:
            pickle.dump(parameters, f)

    def _save_weights(self, save_folder):
        save_path = os.path.join(save_folder, "weights.h5")
        self.model.save_weights(save_path)

    def _build(self):
        self._build_encoder()
        self._build_decoder()
        self._build_autoencoder()

    def _build_autoencoder(self):
        model_input = self._model_input
        model_output = self.decoder(self.encoder(model_input))
        self.model = Model(model_input, model_output, name="autoencoder")

    def _build_decoder(self):
        decoder_input = self._add_decoder_input()
        dense_layer = self._add_dense_layer(decoder_input)
        reshape_layer = self._add_reshape_layer(dense_layer)
        conv_transpose_layers = self._add_conv_transpose_layers(reshape_layer)
        decoder_output = self._add_decoder_output(conv_transpose_layers)
        self.decoder = Model(decoder_input, decoder_output, name="decoder")

    def _add_decoder_input(self):
        return Input(shape=self.latent_space_dim, name="decoder_input")

    def _add_dense_layer(self, decoder_input):
        num_neurons = np.prod(self._shape_before_bottleneck) # [1, 2, 4] -> 8
        dense_layer = Dense(num_neurons, name="decoder_dense")(decoder_input)
        return dense_layer

    def _add_reshape_layer(self, dense_layer):
        return Reshape(self._shape_before_bottleneck)(dense_layer)

    def _add_conv_transpose_layers(self, x):
        """Add conv transpose blocks."""
        # loop through all the conv layers in reverse order and stop at the
        # first layer
        for layer_index in reversed(range(1, self._num_conv_layers)):
            x = self._add_conv_transpose_layer(layer_index, x)
        return x

    def _add_conv_transpose_layer(self, layer_index, x):
        layer_num = self._num_conv_layers - layer_index
        conv_transpose_layer = Conv2DTranspose(
            filters=self.conv_filters[layer_index],
            kernel_size=self.conv_kernels[layer_index],
            strides=self.conv_strides[layer_index],
            padding="same",
            name=f"decoder_conv_transpose_layer_{layer_num}"
        )
        x = conv_transpose_layer(x)
        x = ReLU(name=f"decoder_relu_{layer_num}")(x)
        x = BatchNormalization(name=f"decoder_bn_{layer_num}")(x)
        return x

    def _add_decoder_output(self, x):
        conv_transpose_layer = Conv2DTranspose(
            filters=1,
            kernel_size=self.conv_kernels[0],
            strides=self.conv_strides[0],
            padding="same",
            name=f"decoder_conv_transpose_layer_{self._num_conv_layers}"
        )
        x = conv_transpose_layer(x)
        output_layer = Activation("sigmoid", name="sigmoid_layer")(x)
        return output_layer

    def _build_encoder(self):
        encoder_input = self._add_encoder_input()
        conv_layers = self._add_conv_layers(encoder_input)
        bottleneck = self._add_bottleneck(conv_layers)
        self._model_input = encoder_input
        self.encoder = Model(encoder_input, bottleneck, name="encoder")

    def _add_encoder_input(self):
        return Input(shape=self.input_shape, name="encoder_input")

    def _add_conv_layers(self, encoder_input):
        """Create all convolutional blocks in encoder."""
        x = encoder_input
        for layer_index in range(self._num_conv_layers):
            x = self._add_conv_layer(layer_index, x)
        return x

    def _add_conv_layer(self, layer_index, x):
        """Add a convolutional block to a graph of layers, consisting of
        conv 2d + ReLU + batch normalization.
        """
        layer_number = layer_index + 1
        conv_layer = Conv2D(
            filters=self.conv_filters[layer_index],
            kernel_size=self.conv_kernels[layer_index],
            strides=self.conv_strides[layer_index],
            padding="same",
            name=f"encoder_conv_layer_{layer_number}"
        )
        x = conv_layer(x)
        x = ReLU(name=f"encoder_relu_{layer_number}")(x)
        x = BatchNormalization(name=f"encoder_bn_{layer_number}")(x)
        return x

    def _add_bottleneck(self, x):
        """Flatten data and add bottleneck with Guassian sampling (Dense
        layer).
        """
        self._shape_before_bottleneck = K.int_shape(x)[1:]
        x = Flatten()(x)
        self.mu = Dense(self.latent_space_dim, name="mu")(x)
        self.log_variance = Dense(self.latent_space_dim,
                                  name="log_variance")(x)

        def sample_point_from_normal_distribution(args):
            mu, log_variance = args
            epsilon = K.random_normal(shape=K.shape(self.mu), mean=0.,
                                      stddev=1.)
            sampled_point = mu + K.exp(log_variance / 2) * epsilon
            return sampled_point

        x = Lambda(sample_point_from_normal_distribution,
                   name="encoder_output")([self.mu, self.log_variance])
        return x

# %%
import os

import numpy as np


LEARNING_RATE = 0.0005
BATCH_SIZE = 64
EPOCHS = 150

SPECTROGRAMS_PATH = "/content/drive/MyDrive/Spectogram/"


def load_fsdd(spectrograms_path):
    #This is an empty list and we are gonna fill it with spectrogram
    x_train = []
    #We are going through all the spectogram
    for root, _, file_names in os.walk(spectrograms_path):
        for file_name in file_names:
            file_path = os.path.join(root, file_name)
            spectrogram = np.load(file_path) # (Comes out of spectrograms -> n_bins, n_frames , adding one extra dimension -> 1)
            x_train.append(spectrogram)
    #x_train is all the spectrogram
    x_train = np.array(x_train)
    #We are treating the spectograms as grey scale images
    x_train = x_train[..., np.newaxis] # -> (Number of samples -> 3000 , Number of bins -> 256 , Number of frames  64 , One extra dimension -> 1)
    return x_train


def train(x_train, learning_rate, batch_size, epochs):
    autoencoder = VAE(
        input_shape=(256, 64, 1),
        conv_filters=(512, 256, 128, 64, 32),
        conv_kernels=(3, 3, 3, 3, 3),
        conv_strides=(2, 2, 2, 2, (2, 1)),
        latent_space_dim=128
    )
    autoencoder.summary()
    autoencoder.compile(learning_rate)
    autoencoder.train(x_train, batch_size, epochs)
    return autoencoder

# %%
if __name__ == "__main__":
    x_train = load_fsdd(SPECTROGRAMS_PATH)
    autoencoder = train(x_train, LEARNING_RATE, BATCH_SIZE, EPOCHS)
    autoencoder.save("model")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/keras/src/layers/normalization/batch_normalization.py:883: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  encoder_input (InputLayer)  [(None, 256, 64, 1)]         0         []
#
#  encoder_conv_layer_1 (Conv  (None, 128, 32, 512)         5120      ['encoder_input[0][0]']
#  2D)
#
#  encoder_relu_1 (ReLU)       (None, 128, 32, 512)         0         ['encoder_conv_layer_1[0][0]']
#
#  encoder_bn_1 (BatchNormali  (None, 128, 32, 512)         2048      ['encoder_relu_1[0][0]']
#  zation)
#
#  encoder_conv_layer_2 (Conv  (None, 64, 16, 256)          1179904   ['encoder_bn_1[0][0]']
#  2D)
#
#  encoder_relu_2 (ReLU)       (None, 64, 16, 256)          0         ['encoder_conv_layer_2[0][0]']
#
#  encoder_bn_2 (BatchNormali  (None, 64, 16, 256)          1024      ['encoder_relu_2[0][0]']
#  zation)
#
#  encoder_conv_layer_3 (Conv  (None, 32, 8, 128)           295040    ['encoder_bn_2[0][0]']
#  2D)
#
#  encoder_relu_3 (ReLU)       (None, 32, 8, 128)           0         ['encoder_conv_layer_3[0][0]']
#
#  encoder_bn_3 (BatchNormali  (None, 32, 8, 128)           512       ['encoder_relu_3[0][0]']
#  zation)
#
#  encoder_conv_layer_4 (Conv  (None, 16, 4, 64)            73792     ['encoder_bn_3[0][0]']
#  2D)
#
#  encoder_relu_4 (ReLU)       (None, 16, 4, 64)            0         ['encoder_conv_layer_4[0][0]']
#
#  encoder_bn_4 (BatchNormali  (None, 16, 4, 64)            256       ['encoder_relu_4[0][0]']
#  zation)
#
#  encoder_conv_layer_5 (Conv  (None, 8, 4, 32)             18464     ['encoder_bn_4[0][0]']
#  2D)
#
#  encoder_relu_5 (ReLU)       (None, 8, 4, 32)             0         ['encoder_conv_layer_5[0][0]']
#
#  encoder_bn_5 (BatchNormali  (None, 8, 4, 32)             128       ['encoder_relu_5[0][0]']
#  zation)
#
#  flatten (Flatten)           (None, 1024)                 0         ['encoder_bn_5[0][0]']
#
#  mu (Dense)                  (None, 128)                  131200    ['flatten[0][0]']
#
#  log_variance (Dense)        (None, 128)                  131200    ['flatten[0][0]']
#
#  encoder_output (Lambda)     (None, 128)                  0         ['mu[0][0]',
#                                                                      'log_variance[0][0]']
#
# ==================================================================================================
# Total params: 1838688 (7.01 MB)
# Trainable params: 1836704 (7.01 MB)
# Non-trainable params: 1984 (7.75 KB)
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 128)]             0
#
#  decoder_dense (Dense)       (None, 1024)              132096
#
#  reshape (Reshape)           (None, 8, 4, 32)          0
#
#  decoder_conv_transpose_lay  (None, 16, 4, 32)         9248
#  er_1 (Conv2DTranspose)
#
#  decoder_relu_1 (ReLU)       (None, 16, 4, 32)         0
#
#  decoder_bn_1 (BatchNormali  (None, 16, 4, 32)         128
#  zation)
#
#  decoder_conv_transpose_lay  (None, 32, 8, 64)         18496
#  er_2 (Conv2DTranspose)
#
#  decoder_relu_2 (ReLU)       (None, 32, 8, 64)         0
#
#  decoder_bn_2 (BatchNormali  (None, 32, 8, 64)         256
#  zation)
#
#  decoder_conv_transpose_lay  (None, 64, 16, 128)       73856
#  er_3 (Conv2DTranspose)
#
#  decoder_relu_3 (ReLU)       (None, 64, 16, 128)       0
#
#  decoder_bn_3 (BatchNormali  (None, 64, 16, 128)       512
#  zation)
#
#  decoder_conv_transpose_lay  (None, 128, 32, 256)      295168
#  er_4 (Conv2DTranspose)
#
#  decoder_relu_4 (ReLU)       (None, 128, 32, 256)      0
#
#  decoder_bn_4 (BatchNormali  (None, 128, 32, 256)      1024
#  zation)
#
#  decoder_conv_transpose_lay  (None, 256, 64, 1)        2305
#  er_5 (Conv2DTranspose)
#
#  sigmoid_layer (Activation)  (None, 256, 64, 1)        0
#
# =================================================================
# Total params: 533089 (2.03 MB)
# Trainable params: 532129 (2.03 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 256, 64, 1)]      0
#
#  encoder (Functional)        (None, 128)               1838688
#
#  decoder (Functional)        (None, 256, 64, 1)        533089
#
# =================================================================
# Total params: 2371777 (9.05 MB)
# Trainable params: 2368833 (9.04 MB)
# Non-trainable params: 2944 (11.50 KB)
# _________________________________________________________________
# Train on 3000 samples
# Epoch 1/150
# 3000/3000 [==============================] - 41s 14ms/sample - loss: 187.7893 - _calculate_reconstruction_loss: 0.1575 - _calculate_kl_loss: 30.2554
# Epoch 2/150
# 3000/3000 [==============================] - 24s 8ms/sample - loss: 52.3170 - _calculate_reconstruction_loss: 0.0451 - _calculate_kl_loss: 7.2017
# Epoch 3/150
# 3000/3000 [==============================] - 25s 8ms/sample - loss: 30.4389 - _calculate_reconstruction_loss: 0.0257 - _calculate_kl_loss: 4.7720
# Epoch 4/150
# 3000/3000 [==============================] - 25s 8ms/sample - loss: 24.6131 - _calculate_reconstruction_loss: 0.0206 - _calculate_kl_loss: 4.0256
# Epoch 5/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 21.7127 - _calculate_reconstruction_loss: 0.0184 - _calculate_kl_loss: 3.2690
# Epoch 6/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 20.3720 - _calculate_reconstruction_loss: 0.0173 - _calculate_kl_loss: 3.0532
# Epoch 7/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 19.2927 - _calculate_reconstruction_loss: 0.0162 - _calculate_kl_loss: 3.0578
# Epoch 8/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 17.7440 - _calculate_reconstruction_loss: 0.0150 - _calculate_kl_loss: 2.7334
# Epoch 9/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 15.8540 - _calculate_reconstruction_loss: 0.0134 - _calculate_kl_loss: 2.5010
# Epoch 10/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 13.9854 - _calculate_reconstruction_loss: 0.0117 - _calculate_kl_loss: 2.2553
# Epoch 11/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 12.6434 - _calculate_reconstruction_loss: 0.0106 - _calculate_kl_loss: 2.0720
# Epoch 12/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 11.6092 - _calculate_reconstruction_loss: 0.0097 - _calculate_kl_loss: 1.9488
# Epoch 13/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 10.7831 - _calculate_reconstruction_loss: 0.0090 - _calculate_kl_loss: 1.8003
# Epoch 14/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 10.5252 - _calculate_reconstruction_loss: 0.0087 - _calculate_kl_loss: 1.8077
# Epoch 15/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 10.0978 - _calculate_reconstruction_loss: 0.0084 - _calculate_kl_loss: 1.7183
# Epoch 16/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 9.8679 - _calculate_reconstruction_loss: 0.0082 - _calculate_kl_loss: 1.6482
# Epoch 17/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 9.7818 - _calculate_reconstruction_loss: 0.0081 - _calculate_kl_loss: 1.6985
# Epoch 18/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 9.5888 - _calculate_reconstruction_loss: 0.0079 - _calculate_kl_loss: 1.6976
# Epoch 19/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 9.6229 - _calculate_reconstruction_loss: 0.0079 - _calculate_kl_loss: 1.6894
# Epoch 20/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 9.4065 - _calculate_reconstruction_loss: 0.0077 - _calculate_kl_loss: 1.6907
# Epoch 21/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 9.3109 - _calculate_reconstruction_loss: 0.0076 - _calculate_kl_loss: 1.7095
# Epoch 22/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 9.0363 - _calculate_reconstruction_loss: 0.0073 - _calculate_kl_loss: 1.6878
# Epoch 23/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 8.8411 - _calculate_reconstruction_loss: 0.0071 - _calculate_kl_loss: 1.6932
# Epoch 24/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 8.5516 - _calculate_reconstruction_loss: 0.0069 - _calculate_kl_loss: 1.6638
# Epoch 25/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 8.4901 - _calculate_reconstruction_loss: 0.0068 - _calculate_kl_loss: 1.7348
# Epoch 26/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 8.2447 - _calculate_reconstruction_loss: 0.0066 - _calculate_kl_loss: 1.6720
# Epoch 27/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 8.2915 - _calculate_reconstruction_loss: 0.0066 - _calculate_kl_loss: 1.6706
# Epoch 28/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 8.2290 - _calculate_reconstruction_loss: 0.0065 - _calculate_kl_loss: 1.7129
# Epoch 29/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 8.3578 - _calculate_reconstruction_loss: 0.0066 - _calculate_kl_loss: 1.7278
# Epoch 30/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 8.3070 - _calculate_reconstruction_loss: 0.0065 - _calculate_kl_loss: 1.7741
# Epoch 31/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 8.0116 - _calculate_reconstruction_loss: 0.0064 - _calculate_kl_loss: 1.6543
# Epoch 32/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 8.2066 - _calculate_reconstruction_loss: 0.0065 - _calculate_kl_loss: 1.6928
# Epoch 33/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 8.1076 - _calculate_reconstruction_loss: 0.0064 - _calculate_kl_loss: 1.7017
# Epoch 34/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.9433 - _calculate_reconstruction_loss: 0.0062 - _calculate_kl_loss: 1.7063
# Epoch 35/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.9005 - _calculate_reconstruction_loss: 0.0062 - _calculate_kl_loss: 1.6614
# Epoch 36/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.8503 - _calculate_reconstruction_loss: 0.0062 - _calculate_kl_loss: 1.6672
# Epoch 37/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.8810 - _calculate_reconstruction_loss: 0.0062 - _calculate_kl_loss: 1.6753
# Epoch 38/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.9428 - _calculate_reconstruction_loss: 0.0062 - _calculate_kl_loss: 1.7170
# Epoch 39/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.9286 - _calculate_reconstruction_loss: 0.0062 - _calculate_kl_loss: 1.7376
# Epoch 40/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.8089 - _calculate_reconstruction_loss: 0.0061 - _calculate_kl_loss: 1.6750
# Epoch 41/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.8014 - _calculate_reconstruction_loss: 0.0061 - _calculate_kl_loss: 1.6690
# Epoch 42/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.8709 - _calculate_reconstruction_loss: 0.0062 - _calculate_kl_loss: 1.6573
# Epoch 43/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.6762 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.6406
# Epoch 44/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.8295 - _calculate_reconstruction_loss: 0.0061 - _calculate_kl_loss: 1.7081
# Epoch 45/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.7045 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.6680
# Epoch 46/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.7403 - _calculate_reconstruction_loss: 0.0061 - _calculate_kl_loss: 1.6668
# Epoch 47/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.6787 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.6681
# Epoch 48/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.7078 - _calculate_reconstruction_loss: 0.0061 - _calculate_kl_loss: 1.6572
# Epoch 49/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.7431 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.6940
# Epoch 50/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.6924 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.6845
# Epoch 51/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.7957 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.7651
# Epoch 52/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.6667 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.6763
# Epoch 53/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.6450 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.6597
# Epoch 54/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.8733 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.8480
# Epoch 55/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.7648 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.7814
# Epoch 56/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.6251 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.6552
# Epoch 57/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5751 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6484
# Epoch 58/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5963 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6830
# Epoch 59/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5619 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6508
# Epoch 60/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5652 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6851
# Epoch 61/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5359 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6904
# Epoch 62/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5798 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6922
# Epoch 63/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5676 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6732
# Epoch 64/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5250 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6674
# Epoch 65/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.6547 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.6734
# Epoch 66/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5416 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6834
# Epoch 67/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5031 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6200
# Epoch 68/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5655 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6804
# Epoch 69/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5412 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6704
# Epoch 70/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5506 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6643
# Epoch 71/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.7006 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.8235
# Epoch 72/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.6674 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.7170
# Epoch 73/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.6080 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.7429
# Epoch 74/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5153 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6832
# Epoch 75/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4827 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6697
# Epoch 76/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4441 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6378
# Epoch 77/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4683 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6815
# Epoch 78/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4614 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6420
# Epoch 79/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5044 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6777
# Epoch 80/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4354 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6617
# Epoch 81/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5327 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6955
# Epoch 82/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4860 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6502
# Epoch 83/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4659 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6575
# Epoch 84/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.7591 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.8854
# Epoch 85/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5098 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6739
# Epoch 86/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4738 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6583
# Epoch 87/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4706 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6687
# Epoch 88/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4184 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6411
# Epoch 89/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4338 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6446
# Epoch 90/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5733 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.7334
# Epoch 91/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5105 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6791
# Epoch 92/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5080 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6479
# Epoch 93/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4114 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6639
# Epoch 94/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4345 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6606
# Epoch 95/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5376 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.7357
# Epoch 96/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4957 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.7013
# Epoch 97/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4805 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6464
# Epoch 98/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4177 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6653
# Epoch 99/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3622 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6221
# Epoch 100/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3958 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6465
# Epoch 101/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4723 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6968
# Epoch 102/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4076 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6707
# Epoch 103/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4072 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6625
# Epoch 104/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4296 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6921
# Epoch 105/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4630 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6687
# Epoch 106/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4152 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6815
# Epoch 107/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3719 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6226
# Epoch 108/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4406 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6855
# Epoch 109/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4103 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6585
# Epoch 110/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4078 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6563
# Epoch 111/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4227 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6678
# Epoch 112/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3945 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6558
# Epoch 113/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4164 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6708
# Epoch 114/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4067 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6705
# Epoch 115/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3866 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6433
# Epoch 116/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3786 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6825
# Epoch 117/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3693 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6614
# Epoch 118/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3582 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6606
# Epoch 119/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3866 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6689
# Epoch 120/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4008 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6922
# Epoch 121/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4315 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6601
# Epoch 122/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3895 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6882
# Epoch 123/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 18.3737 - _calculate_reconstruction_loss: 0.0075 - _calculate_kl_loss: 10.8640
# Epoch 124/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 8.8284 - _calculate_reconstruction_loss: 0.0068 - _calculate_kl_loss: 2.0716
# Epoch 125/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.9041 - _calculate_reconstruction_loss: 0.0063 - _calculate_kl_loss: 1.6431
# Epoch 126/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.7444 - _calculate_reconstruction_loss: 0.0061 - _calculate_kl_loss: 1.6095
# Epoch 127/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.6756 - _calculate_reconstruction_loss: 0.0060 - _calculate_kl_loss: 1.6883
# Epoch 128/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5839 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6360
# Epoch 129/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5967 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6811
# Epoch 130/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5358 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6865
# Epoch 131/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5108 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6721
# Epoch 132/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4989 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6611
# Epoch 133/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5031 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6837
# Epoch 134/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5224 - _calculate_reconstruction_loss: 0.0059 - _calculate_kl_loss: 1.6547
# Epoch 135/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4098 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6226
# Epoch 136/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.5183 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6825
# Epoch 137/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4462 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6243
# Epoch 138/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3906 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6259
# Epoch 139/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4334 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6504
# Epoch 140/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4337 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6388
# Epoch 141/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3659 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6136
# Epoch 142/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3909 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6210
# Epoch 143/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4168 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6757
# Epoch 144/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4186 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6637
# Epoch 145/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3645 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6270
# Epoch 146/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4527 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6695
# Epoch 147/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4441 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6719
# Epoch 148/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3447 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6449
# Epoch 149/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.3673 - _calculate_reconstruction_loss: 0.0057 - _calculate_kl_loss: 1.6441
# Epoch 150/150
# 3000/3000 [==============================] - 26s 9ms/sample - loss: 7.4712 - _calculate_reconstruction_loss: 0.0058 - _calculate_kl_loss: 1.6748

# %%
import librosa



class SoundGenerator:
    """SoundGenerator is responsible for generating audios from
    spectrograms.
    """

    def __init__(self, vae, hop_length):
        #We have vae , hop length , min max normalizer
        self.vae = vae
        self.hop_length = hop_length
        self._min_max_normaliser = MinMaxNormaliser(0, 1)
        #The spectogram we create should be normalized



    def generate(self, spectrograms, min_max_values):
        #We will reconstruct spectrogram and min max values
        generated_spectrograms, latent_representations = \
            self.vae.reconstruct(spectrograms)
            #it will give us generated spectrogram and latent representations

        #We need to convert generated spectrogram into audio signals using generated spectrogram and min max values
        signals = self.convert_spectrograms_to_audio(generated_spectrograms, min_max_values)
        return signals, latent_representations

    def convert_spectrograms_to_audio(self, spectrograms, min_max_values):
        signals = []
        for spectrogram, min_max_value in zip(spectrograms, min_max_values):
            # reshape the log spectrogram
            log_spectrogram = spectrogram[:, :, 0]
            # apply denormalisation
            denorm_log_spec = self._min_max_normaliser.denormalise(
                log_spectrogram, min_max_value["min"], min_max_value["max"])
            # log spectrogram -> spectrogram
            spec = librosa.db_to_amplitude(denorm_log_spec)
            # apply Griffin-Lim (inverse short fourier transform)
            signal = librosa.istft(spec, hop_length=self.hop_length)
            # append signal to "signals"
            signals.append(signal)
        return signals

# %%
import os
import pickle

import numpy as np
import soundfile as sf



import os
import pickle
import numpy as np
import soundfile as sf

HOP_LENGTH = 256
SAVE_DIR_ORIGINAL = "/content/drive/MyDrive/original"
SAVE_DIR_GENERATED = "/content/drive/MyDrive/generated"
MIN_MAX_VALUES_PATH = "/content/drive/MyDrive/Min_max_value/min_max_values.pkl"
SPECTROGRAMS_PATH = "/content/drive/MyDrive/Spectogram"  # Replace with your actual path

# The rest of your code...


import os
import numpy as np

def load_fsdd(spectrograms_path):
    x_train = []
    file_paths = []
    for root, _, file_names in os.walk(spectrograms_path):
        for file_name in file_names:
            file_path = os.path.join(root, file_name)
            try:
                spectrogram = np.load(file_path) # (n_bins, n_frames, 1)
                x_train.append(spectrogram)
                file_paths.append(file_path)
            except Exception as e:
                print(f"Error loading file '{file_path}': {str(e)}")
    if not x_train:
        print("No valid spectrograms found in the directory.")
        return None, None
    x_train = np.array(x_train)
    x_train = x_train[..., np.newaxis] # -> (3000, 256, 64, 1)
    return x_train, file_paths


    if x_train:
        x_train = np.array(x_train)
        return x_train, file_paths
    else:
        print("No valid spectrograms found in the directory.")
        return None, None


def select_spectrograms(spectrograms,
                        file_paths,
                        min_max_values,
                        num_spectrograms=2):
    sampled_indexes = np.random.choice(range(len(spectrograms)), num_spectrograms)
    sampled_spectrogrmas = spectrograms[sampled_indexes]
    file_paths = [file_paths[index] for index in sampled_indexes]
    sampled_min_max_values = [min_max_values[file_path] for file_path in
                           file_paths]
    print(file_paths)
    print(sampled_min_max_values)
    return sampled_spectrogrmas, sampled_min_max_values


def save_signals(signals, save_dir, sample_rate=22050):
    for i, signal in enumerate(signals):
        save_path = os.path.join(save_dir, str(i) + ".wav")
        sf.write(save_path, signal, sample_rate)


if __name__ == "__main__":
    # initialise sound generator
    vae = VAE.load("model")
    sound_generator = SoundGenerator(vae, HOP_LENGTH)

    # load spectrograms + min max values
    with open(MIN_MAX_VALUES_PATH, "rb") as f:
        min_max_values = pickle.load(f)

    specs, file_paths = load_fsdd(SPECTROGRAMS_PATH)

    # sample spectrograms + min max values
    sampled_specs, sampled_min_max_values = select_spectrograms(specs,
                                                                file_paths,
                                                                min_max_values,
                                                                5)

    # generate audio for sampled spectrograms
    signals, _ = sound_generator.generate(sampled_specs,
                                          sampled_min_max_values)

    # convert spectrogram samples to audio
    original_signals = sound_generator.convert_spectrograms_to_audio(
        sampled_specs, sampled_min_max_values)

    # save audio signals
    save_signals(signals, SAVE_DIR_GENERATED)
    save_signals(original_signals, SAVE_DIR_ORIGINAL)
# Out:
# ['/content/drive/MyDrive/Spectogram/2_theo_1.wav.npy', '/content/drive/MyDrive/Spectogram/3_theo_6.wav.npy', '/content/drive/MyDrive/Spectogram/9_lucas_1.wav.npy', '/content/drive/MyDrive/Spectogram/4_theo_25.wav.npy', '/content/drive/MyDrive/Spectogram/6_lucas_14.wav.npy']
# [{'min': -73.64099, 'max': 6.3590093}, {'min': -74.73115, 'max': 5.2688527}, {'min': -55.75312, 'max': 24.24688}, {'min': -54.043983, 'max': 25.956018}, {'min': -55.34587, 'max': 24.654129}]
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
